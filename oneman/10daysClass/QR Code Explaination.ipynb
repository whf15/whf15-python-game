# %%
from MyQR import myqr
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
words = "https://www.wanmen.org/"
version, level, qr_name = myqr.run(
    words,
    version=3,
    level='H',
    picture="angelapper.jpg",
    colorized=True,
    contrast=1.0,
    brightness=1.0,
    save_name="wanmenqr.png",
    save_dir=os.getcwd()
)
# Out:
# line 16: mode: byte

# %%
from IPython.display import Image
Image(filename='wanmenqr.png')

# %%
words = "https://www.wanmen.org/"
version, level, qr_name = myqr.run(
    words,
    version=3,
    level='H',
    picture=None,
    colorized=True,
    contrast=1.0,
    brightness=1.0,
    save_name="wamen_b.png",
    save_dir=os.getcwd()
)
# Out:
# line 16: mode: byte

# %%
from IPython.display import Image
Image(filename='wamen_b.png')

# %%
from IPython.display import Image
Image(filename='myqrcode.png')

# %%
words = "my name is joshua"
version, level, qr_name = myqr.run(
    words,
    version=3,
    level='H',
    picture=None,
    colorized=True,
    contrast=1.0,
    brightness=1.0,
    save_name="joshua.png",
    save_dir=os.getcwd()
)
# Out:
# line 16: mode: byte

# %%
from pyzbar.pyzbar import decode
from PIL import Image

decoded_data = decode(Image.open('myqrcode.png'))
print(decoded_data)
# Out:
# [Decoded(data=b'djfladjfladfjadjflajldjadjflkhttp://www.google.com', type='QRCODE')]

# %%
decoded_data[0].type
# Out:
# 'QRCODE'

# %%
from pyzbar.pyzbar import decode
from PIL import Image

decoded_wx_data = decode(Image.open('wx_gaFZzbFLDA==.jpeg'))
print(decoded_wx_data)
# Out:
# [Decoded(data=b'https://login.weixin.qq.com/l/gaFZzbFLDA==', type='QRCODE')]
